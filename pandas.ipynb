# %%
#pip install pandas

# %%
import pandas as pd

# %%
data = { 'apples' :[2,8,9,10],
        "grapes" :[7,7,45,9]

}

# %%
x = pd.DataFrame(data)
x
# Out:
#    apples  grapes
# 0       2       7
# 1       8       7
# 2       9      45
# 3      10       9

# %%
x = pd.DataFrame(data,index=["steve","keshav","hiba","haru"])
x
# Out:
#         apples  grapes
# steve        2       7
# keshav       8       7
# hiba         9      45
# haru        10       9

# %%
x.loc["steve"]
# Out:
# apples    2
# grapes    7
# Name: steve, dtype: int64

# %%
df = pd.read_csv("/Book1.csv")
df
# Out:
#                  Unnamed: 0     ID    Name                 Age Photo  \
# 0                         0      0  158023            L. Messi    31
# 1                         1      1   20801   Cristiano Ronaldo    33
# 2                         2      2  190871           Neymar Jr    26
# 3                         3      3  193080              De Gea    27
# 4                         4      4  192985        K. De Bruyne    27
# 5                       ...    ...     ...                 ...   ...
# 6                     18202  18202  238813        J. Lundstram    19
# 7                     18203  18203  243165  N. Christoffersson    19
# 8                     18204  18204  241638           B. Worman    16
# 9                     18205  18205  246268      D. Walker-Rice    17
# 10                    18206  18206  246269           G. Nugent    16
# 11  18207 rows ? 89 columns    NaN     NaN                 NaN   NaN
#
#                                        Nationality       Flag  \
# ...

# %%
df.head(4)
# Out:
#   Unnamed: 0 ID    Name                Age Photo  \
# 0          0  0  158023           L. Messi    31
# 1          1  1   20801  Cristiano Ronaldo    33
# 2          2  2  190871          Neymar Jr    26
# 3          3  3  193080             De Gea    27
#
#                                       Nationality       Flag  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png  Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png   Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png     Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png      Spain
#
#                                Overall Potential Club  ... Marking  \
# 0  https://cdn.sofifa.org/flags/52.png        94   94  ...      96
# 1  https://cdn.sofifa.org/flags/38.png        94   94  ...      95
# 2  https://cdn.sofifa.org/flags/54.png        92   93  ...      94
# 3  https://cdn.sofifa.org/flags/45.png        91   93  ...      68
#
# ...

# %%
df.tail(5)
# Out:
#                  Unnamed: 0     ID    Name                 Age Photo  \
# 7                     18203  18203  243165  N. Christoffersson    19
# 8                     18204  18204  241638           B. Worman    16
# 9                     18205  18205  246268      D. Walker-Rice    17
# 10                    18206  18206  246269           G. Nugent    16
# 11  18207 rows ? 89 columns    NaN     NaN                 NaN   NaN
#
#                                        Nationality     Flag  \
# 7   https://cdn.sofifa.org/players/4/19/243165.png   Sweden
# 8   https://cdn.sofifa.org/players/4/19/241638.png  England
# 9   https://cdn.sofifa.org/players/4/19/246268.png  England
# 10  https://cdn.sofifa.org/players/4/19/246269.png  England
# 11                                             NaN      NaN
#
#                                 Overall Potential Club  ... Marking  \
# 7   https://cdn.sofifa.org/flags/46.png        47   63  ...      42
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      12 non-null     object
#  1   ID              11 non-null     object
#  2   Name            11 non-null     object
#  3   Age             11 non-null     object
#  4   Photo           11 non-null     object
#  5   Nationality     11 non-null     object
#  6   Flag            11 non-null     object
#  7   Overall         11 non-null     object
#  8   Potential       11 non-null     object
#  9   Club            11 non-null     object
#  10  ...             11 non-null     object
#  11  Composure       11 non-null     object
#  12  Marking         11 non-null     object
#  13  StandingTackle  11 non-null     object
#  14  SlidingTackle   11 non-null     object
#  15  GKDiving        11 non-null     object
#  16  GKHandling      11 non-null     object
# ...

# %%
df.shape
# Out:
# (12, 22)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', '...', 'Composure', 'Marking',
#        'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause',
#        'Unnamed: 21'],
#       dtype='object')

# %%
df.Name
# Out:
# 0     158023
# 1      20801
# 2     190871
# 3     193080
# 4     192985
# 5        ...
# 6     238813
# 7     243165
# 8     241638
# 9     246268
# 10    246269
# 11       NaN
# Name: Name, dtype: object

# %%
df.isnull()
# Out:
#     Unnamed: 0     ID   Name    Age  Photo  Nationality   Flag  Overall  \
# 0        False  False  False  False  False        False  False    False
# 1        False  False  False  False  False        False  False    False
# 2        False  False  False  False  False        False  False    False
# 3        False  False  False  False  False        False  False    False
# 4        False  False  False  False  False        False  False    False
# 5        False  False  False  False  False        False  False    False
# 6        False  False  False  False  False        False  False    False
# 7        False  False  False  False  False        False  False    False
# 8        False  False  False  False  False        False  False    False
# 9        False  False  False  False  False        False  False    False
# 10       False  False  False  False  False        False  False    False
# 11       False   True   True   True   True         True   True     True
#
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0        0
# ID                1
# Name              1
# Age               1
# Photo             1
# Nationality       1
# Flag              1
# Overall           1
# Potential         1
# Club              1
# ...               1
# Composure         1
# Marking           1
# StandingTackle    1
# SlidingTackle     1
# GKDiving          1
# GKHandling        1
# GKKicking         1
# GKPositioning     1
# GKReflexes        1
# Release Clause    1
# Unnamed: 21       1
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0        0
# ID                0
# Name              0
# Age               0
# Photo             0
# Nationality       0
# Flag              0
# Overall           0
# Potential         0
# Club              0
# ...               0
# Composure         0
# Marking           0
# StandingTackle    0
# SlidingTackle     0
# GKDiving          0
# GKHandling        0
# GKKicking         0
# GKPositioning     0
# GKReflexes        0
# Release Clause    0
# Unnamed: 21       0
# dtype: int64

# %%
# fetch data from csv file using numpy pandas

# %%
import numpy as np

# %%
import pandas as pd

# %%
data_frame = pd.read_csv('/Book1.csv')

# %%
print("Data Frame:")
# Out:
# Data Frame:

# %%
print(data_frame)
# Out:
#                  Unnamed: 0     ID    Name                 Age Photo  \
# 0                         0      0  158023            L. Messi    31
# 1                         1      1   20801   Cristiano Ronaldo    33
# 2                         2      2  190871           Neymar Jr    26
# 3                         3      3  193080              De Gea    27
# 4                         4      4  192985        K. De Bruyne    27
# 5                       ...    ...     ...                 ...   ...
# 6                     18202  18202  238813        J. Lundstram    19
# 7                     18203  18203  243165  N. Christoffersson    19
# 8                     18204  18204  241638           B. Worman    16
# 9                     18205  18205  246268      D. Walker-Rice    17
# 10                    18206  18206  246269           G. Nugent    16
# 11  18207 rows ? 89 columns    NaN     NaN                 NaN   NaN
#
#                                        Nationality       Flag  \
# ...

# %%
numpy_array = data_frame.to_numpy()

# %%
print("\nNumPy Array:")
# Out:
# NumPy Array:

# %%
print(numpy_array)
# Out:
# [['0' '0' '158023' 'L. Messi' '31'
#   'https://cdn.sofifa.org/players/4/19/158023.png' 'Argentina'
#   'https://cdn.sofifa.org/flags/52.png' '94' '94' 'FC Barcelona' '...'
#   '96' '33' '28' '26' '6' '11' '15' '14' '8' '?226.5M']
#  ['1' '1' '20801' 'Cristiano Ronaldo' '33'
#   'https://cdn.sofifa.org/players/4/19/20801.png' 'Portugal'
#   'https://cdn.sofifa.org/flags/38.png' '94' '94' 'Juventus' '...' '95'
#   '28' '31' '23' '7' '11' '15' '14' '11' '?127.1M']
#  ['2' '2' '190871' 'Neymar Jr' '26'
#   'https://cdn.sofifa.org/players/4/19/190871.png' 'Brazil'
#   'https://cdn.sofifa.org/flags/54.png' '92' '93' 'Paris Saint-Germain'
#   '...' '94' '27' '24' '33' '9' '9' '15' '15' '11' '?228.1M']
#  ['3' '3' '193080' 'De Gea' '27'
#   'https://cdn.sofifa.org/players/4/19/193080.png' 'Spain'
#   'https://cdn.sofifa.org/flags/45.png' '91' '93' 'Manchester United'
#   '...' '68' '15' '21' '13' '90' '85' '87' '88' '94' '?138.6M']
#  ['4' '4' '192985' 'K. De Bruyne' '27'
# ...
