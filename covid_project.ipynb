# %%
import pandas as pd

# %%
covid = pd.read_csv("/covidBook1.csv")
covid
# Out:
#     USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0       2             1    1             1    3/5/2020       97          1
# 1       2             1    2             1    3/6/2020       97          1
# 2       2             1    2             2    9/6/2020        1          2
# 3       2             1    1             1   12/6/2020       97          2
# 4       2             1    2             1  21/06/2020       97          2
# 5       2             1    1             2  9999-99-99        2          1
# 6       2             1    1             1  9999-99-99       97          2
# 7       2             1    1             1  9999-99-99       97          1
# 8       2             1    1             2  9999-99-99        2          2
# 9       2             1    1             2  9999-99-99        2          2
# 10      2             1    1             1  9999-99-99       97          2
# ...

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   USMER                 41 non-null     int64
#  1   MEDICAL_UNIT          41 non-null     int64
#  2   SEX                   41 non-null     int64
#  3   PATIENT_TYPE          41 non-null     int64
#  4   DATE_DIED             41 non-null     object
#  5   INTUBED               41 non-null     int64
#  6   PNEUMONIA             41 non-null     int64
#  7   AGE                   41 non-null     int64
#  8   PREGNANT              41 non-null     int64
#  9   DIABETES              41 non-null     int64
#  10  COPD                  41 non-null     int64
#  11  ASTHMA                41 non-null     int64
#  12  INMSUPR               41 non-null     int64
#  13  HIPERTENSION          41 non-null     int64
#  14  OTHER_DISEASE         41 non-null     int64
# ...

# %%
covid.shape
# Out:
# (41, 21)

# %%
covid.fillna(value = 0 ,inplace = True)
covid
# Out:
#     USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0       2             1    1             1    3/5/2020       97          1
# 1       2             1    2             1    3/6/2020       97          1
# 2       2             1    2             2    9/6/2020        1          2
# 3       2             1    1             1   12/6/2020       97          2
# 4       2             1    2             1  21/06/2020       97          2
# 5       2             1    1             2  9999-99-99        2          1
# 6       2             1    1             1  9999-99-99       97          2
# 7       2             1    1             1  9999-99-99       97          1
# 8       2             1    1             2  9999-99-99        2          2
# 9       2             1    1             2  9999-99-99        2          2
# 10      2             1    1             1  9999-99-99       97          2
# ...

# %%
covid.columns
# Out:
# Index(['USMER', 'MEDICAL_UNIT', 'SEX', 'PATIENT_TYPE', 'DATE_DIED', 'INTUBED',
#        'PNEUMONIA', 'AGE', 'PREGNANT', 'DIABETES', 'COPD', 'ASTHMA', 'INMSUPR',
#        'HIPERTENSION', 'OTHER_DISEASE', 'CARDIOVASCULAR', 'OBESITY',
#        'RENAL_CHRONIC', 'TOBACCO', 'CLASIFFICATION_FINAL', 'ICU'],
#       dtype='object')

# %%
covid['ICU'].min()
# Out:
# 1

# %%
covid['ICU'].max()
# Out:
# 97

# %%
date_died = covid.DATE_DIED.str.split('/',expand = True)
date_died
# Out:
#              0     1     2
# 0            3     5  2020
# 1            3     6  2020
# 2            9     6  2020
# 3           12     6  2020
# 4           21    06  2020
# 5   9999-99-99  None  None
# 6   9999-99-99  None  None
# 7   9999-99-99  None  None
# 8   9999-99-99  None  None
# 9   9999-99-99  None  None
# 10  9999-99-99  None  None
# 11  9999-99-99  None  None
# 12  9999-99-99  None  None
# 13  9999-99-99  None  None
# 14  9999-99-99  None  None
# 15  9999-99-99  None  None
# 16  9999-99-99  None  None
# 17  9999-99-99  None  None
# 18  9999-99-99  None  None
# 19  9999-99-99  None  None
# 20  9999-99-99  None  None
# 21  9999-99-99  None  None
# 22  9999-99-99  None  None
# 23  9999-99-99  None  None
# 24  9999-99-99  None  None
# 25  9999-99-99  None  None
# 26  9999-99-99  None  None
# 27  9999-99-99  None  None
# 28  9999-99-99  None  None
# 29  9999-99-99  None  None
# 30  9999-99-99  None  None
# 31  9999-99-99  None  None
# 32  9999-99-99  None  None
# ...

# %%
covid = pd.DataFrame({
    'USMER': ['0',]
     'Date_Died': ['3-5-2020']
     'Data_Died': ['0',]

})
# Out:
#   File "<ipython-input-33-04ec0f2fc8ff>", line 2
#     'USMER': ['0',]
#              ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
covid = pd.DataFrame
  "USMER": ['0']
    "Data_Died": ['3-5-2020']
covid["Data_Died_2020"] = data_died[0]
covid["Data_Died_05"] = data_died[0]
covid["Data_Died_03"] = data_died[0]
# Out:
#   File "<ipython-input-30-cac4b8336f05>", line 2
#     "USMER": ['0']
#     ^
# IndentationError: unexpected indent

# %%
print(covid)
# Out:
#    USMER Date_Died
# 0      0  3-5-2020
# 1      1  3-6-2020
# 2      2  9-6-2020

# %%
covid.Died_year = pd.to_numeric(covid.Died_year)
covid.Died_Month = pd.to_numeric(covid.Died_Month)
# covid.Died_Day = pd.to_numeric(covid.Died_Day)

# %%
# covid.DATE_DIED = pd.to_datetime(covid.DATE_DIED)

# %%
covid.head()
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1    3/5/2020       97          1
# 1      2             1    2             1    3/6/2020       97          1
# 2      2             1    2             2    9/6/2020        1          2
# 3      2             1    1             1   12/6/2020       97          2
# 4      2             1    2             1  21/06/2020       97          2
#
#    AGE  PREGNANT  DIABETES  ...  ICU  Died_year  Died_Month  Died_Day  \
# 0   65         2         2  ...   97     2020.0         5.0         3
# 1   72        97         2  ...   97     2020.0         6.0         3
# 2   55        97         1  ...    2     2020.0         6.0         9
# 3   53         2         2  ...   97     2020.0         6.0        12
# 4   68        97         1  ...   97     2020.0         6.0        21
#
#    Died_2020  Died_01  Died_09  2020  01  09
# 0     2020.0        5        3  2020   5   3
# ...

# %%
covid["Died_year"].min()
# Out:
# 2020.0

# %%
covid["Died_year"].max()
# Out:
# 2020.0

# %%
covid.columns
# Out:
# Index(['USMER', 'MEDICAL_UNIT', 'SEX', 'PATIENT_TYPE', 'DATE_DIED', 'INTUBED',
#        'PNEUMONIA', 'AGE', 'PREGNANT', 'DIABETES', 'COPD', 'ASTHMA', 'INMSUPR',
#        'HIPERTENSION', 'OTHER_DISEASE', 'CARDIOVASCULAR', 'OBESITY',
#        'RENAL_CHRONIC', 'TOBACCO', 'CLASIFFICATION_FINAL', 'ICU', 'Died_year',
#        'Died_Month', 'Died_Day', 'Died_2020', 'Died_01', 'Died_09', '2020',
#        '01', '09'],
#       dtype='object')

# %%
covid.mean()
# Out:
# <ipython-input-48-480d5216a122>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   covid.mean()
# USMER                      2.000000
# MEDICAL_UNIT               1.000000
# SEX                        1.512195
# PATIENT_TYPE               1.219512
# INTUBED                   76.121951
# PNEUMONIA                  1.829268
# AGE                       45.292683
# PREGNANT                  50.658537
# DIABETES                   1.829268
# COPD                       2.000000
# ASTHMA                     1.975610
# INMSUPR                    1.975610
# HIPERTENSION               1.853659
# OTHER_DISEASE              1.975610
# CARDIOVASCULAR             1.951220
# OBESITY                    1.926829
# RENAL_CHRONIC              1.926829
# ...

# %%
covid
# Out:
#     USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0       2             1    1             1    3/5/2020       97          1
# 1       2             1    2             1    3/6/2020       97          1
# 2       2             1    2             2    9/6/2020        1          2
# 3       2             1    1             1   12/6/2020       97          2
# 4       2             1    2             1  21/06/2020       97          2
# 5       2             1    1             2  9999-99-99        2          1
# 6       2             1    1             1  9999-99-99       97          2
# 7       2             1    1             1  9999-99-99       97          1
# 8       2             1    1             2  9999-99-99        2          2
# 9       2             1    1             2  9999-99-99        2          2
# 10      2             1    1             1  9999-99-99       97          2
# ...

# %%
covid.AGE.value_counts()
# Out:
# 64    3
# 37    3
# 45    3
# 38    2
# 55    2
# 49    2
# 25    2
# 24    2
# 30    2
# 27    1
# 32    1
# 39    1
# 65    1
# 57    1
# 20    1
# 56    1
# 47    1
# 26    1
# 80    1
# 59    1
# 54    1
# 61    1
# 72    1
# 23    1
# 48    1
# 40    1
# 68    1
# 53    1
# 50    1
# Name: AGE, dtype: int64

# %%
covid.AGE
# Out:
# 0     65
# 1     72
# 2     55
# 3     53
# 4     68
# 5     40
# 6     64
# 7     64
# 8     37
# 9     25
# 10    38
# 11    24
# 12    30
# 13    55
# 14    48
# 15    23
# 16    80
# 17    61
# 18    54
# 19    64
# 20    59
# 21    30
# 22    45
# 23    26
# 24    38
# 25    24
# 26    32
# 27    49
# 28    39
# 29    27
# 30    45
# 31    57
# 32    25
# 33    37
# 34    49
# 35    45
# 36    20
# 37    56
# 38    47
# 39    50
# 40    37
# Name: AGE, dtype: int64

# %%
#matplotlib and seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x = covid.Died_year,y=covid.ICU)
plt.title("Died year vs Icu")
plt.show()
