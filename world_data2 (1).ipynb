# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
#load and read data of world population
data=pd.read_csv('/content/data.csv')
data
# Out:
#       COUNTRY_CODE                   COUNTRY  GHE_CAUSE_CODE  \
# 0              USA  United States of America           490.0
# 1              USA  United States of America          1400.0
# 2              USA  United States of America          1505.0
# 3              USA  United States of America           390.0
# 4              USA  United States of America           110.0
# ...            ...                       ...             ...
# 42137          CHN                     China           840.0
# 42138          CHN                     China          1000.0
# 42139          CHN                     China            85.0
# 42140          CHN                     China          1040.0
# 42141          CHN                       NaN             NaN
#
#                                           GHE_CAUSE_TYPE  \
# 0      Communicable, maternal, perinatal and nutritio...
# 1                               Noncommunicable diseases
# 2                               Noncommunicable diseases
# ...

# %%
#call a head function to print some rows and columns ,by default it can print only 5.
data.head()
# Out:
#   COUNTRY_CODE                   COUNTRY  GHE_CAUSE_CODE  \
# 0          USA  United States of America           490.0
# 1          USA  United States of America          1400.0
# 2          USA  United States of America          1505.0
# 3          USA  United States of America           390.0
# 4          USA  United States of America           110.0
#
#                                       GHE_CAUSE_TYPE  \
# 0  Communicable, maternal, perinatal and nutritio...
# 1                           Noncommunicable diseases
# 2                           Noncommunicable diseases
# 3  Communicable, maternal, perinatal and nutritio...
# 4  Communicable, maternal, perinatal and nutritio...
#
#                 GHE_CAUSE_TITLE    YEAR SEX_CODE AGEGROUP_CODE  POPULATION  \
# 0           Neonatal conditions  2000.0     FMLE      YEARS0-1   1820819.0
# 1          Congenital anomalies  2000.0     FMLE      YEARS0-1   1820819.0
# ...

# %%
#call tail function to print from bottom record by default 5
data.tail()
# Out:
#       COUNTRY_CODE COUNTRY  GHE_CAUSE_CODE  \
# 42137          CHN   China           840.0
# 42138          CHN   China          1000.0
# 42139          CHN   China            85.0
# 42140          CHN   China          1040.0
# 42141          CHN     NaN             NaN
#
#                                           GHE_CAUSE_TYPE  \
# 42137                           Noncommunicable diseases
# 42138                           Noncommunicable diseases
# 42139  Communicable, maternal, perinatal and nutritio...
# 42140                           Noncommunicable diseases
# 42141                                                NaN
#
#              GHE_CAUSE_TITLE    YEAR SEX_CODE AGEGROUP_CODE  POPULATION  \
# 42137       Bipolar disorder  2015.0     FMLE    YEARS80-84   8171467.0
# 42138  Non-migraine headache  2015.0     FMLE    YEARS80-84   8171467.0
# 42139         Genital herpes  2015.0     FMLE    YEARS80-84   8171467.0
# ...

# %%
#finding a shape means how many rows and columns are there
data.shape
# Out:
# (42142, 15)

# %%
#total number of data values
data.size
# Out:
# 632130

# %%
#find each columns name
data.columns
# Out:
# Index(['COUNTRY_CODE', 'COUNTRY', 'GHE_CAUSE_CODE', 'GHE_CAUSE_TYPE',
#        'GHE_CAUSE_TITLE', 'YEAR', 'SEX_CODE', 'AGEGROUP_CODE', 'POPULATION',
#        'DEATHS', 'DEATHS_RATE', 'DEATHS_100K', 'DALY', 'DALY_RATE',
#        'DALY_100K'],
#       dtype='object')

# %%
#To show data types
data.dtypes
# Out:
# COUNTRY_CODE        object
# COUNTRY             object
# GHE_CAUSE_CODE     float64
# GHE_CAUSE_TYPE      object
# GHE_CAUSE_TITLE     object
# YEAR               float64
# SEX_CODE            object
# AGEGROUP_CODE       object
# POPULATION         float64
# DEATHS             float64
# DEATHS_RATE        float64
# DEATHS_100K        float64
# DALY               float64
# DALY_RATE          float64
# DALY_100K          float64
# dtype: object

# %%
#it will give information about indexes,columns,data types and more
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42142 entries, 0 to 42141
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   COUNTRY_CODE     42142 non-null  object
#  1   COUNTRY          42141 non-null  object
#  2   GHE_CAUSE_CODE   42141 non-null  float64
#  3   GHE_CAUSE_TYPE   42141 non-null  object
#  4   GHE_CAUSE_TITLE  42141 non-null  object
#  5   YEAR             42141 non-null  float64
#  6   SEX_CODE         42141 non-null  object
#  7   AGEGROUP_CODE    42141 non-null  object
#  8   POPULATION       42141 non-null  float64
#  9   DEATHS           42141 non-null  float64
#  10  DEATHS_RATE      42141 non-null  float64
#  11  DEATHS_100K      42141 non-null  float64
#  12  DALY             42141 non-null  float64
#  13  DALY_RATE        42141 non-null  float64
#  14  DALY_100K        42141 non-null  float64
# dtypes: float64(9), object(6)
# memory usage: 4.8+ MB

# %%
#To check duplicate data and remove it
data.head()
# Out:
#   COUNTRY_CODE                   COUNTRY  GHE_CAUSE_CODE  \
# 0          USA  United States of America           490.0
# 1          USA  United States of America          1400.0
# 2          USA  United States of America          1505.0
# 3          USA  United States of America           390.0
# 4          USA  United States of America           110.0
#
#                                       GHE_CAUSE_TYPE  \
# 0  Communicable, maternal, perinatal and nutritio...
# 1                           Noncommunicable diseases
# 2                           Noncommunicable diseases
# 3  Communicable, maternal, perinatal and nutritio...
# 4  Communicable, maternal, perinatal and nutritio...
#
#                 GHE_CAUSE_TITLE    YEAR SEX_CODE AGEGROUP_CODE  POPULATION  \
# 0           Neonatal conditions  2000.0     FMLE      YEARS0-1   1820819.0
# 1          Congenital anomalies  2000.0     FMLE      YEARS0-1   1820819.0
# ...

# %%
data.duplicated() #finding duplicate values or data
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 42137    False
# 42138    False
# 42139    False
# 42140    False
# 42141    False
# Length: 42142, dtype: bool

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [COUNTRY_CODE, COUNTRY, GHE_CAUSE_CODE, GHE_CAUSE_TYPE, GHE_CAUSE_TITLE, YEAR, SEX_CODE, AGEGROUP_CODE, POPULATION, DEATHS, DEATHS_RATE, DEATHS_100K, DALY, DALY_RATE, DALY_100K]
# Index: []

# %%
#finding empty values
data.isnull()
# Out:
#        COUNTRY_CODE  COUNTRY  GHE_CAUSE_CODE  GHE_CAUSE_TYPE  GHE_CAUSE_TITLE  \
# 0             False    False           False           False            False
# 1             False    False           False           False            False
# 2             False    False           False           False            False
# 3             False    False           False           False            False
# 4             False    False           False           False            False
# ...             ...      ...             ...             ...              ...
# 42137         False    False           False           False            False
# 42138         False    False           False           False            False
# 42139         False    False           False           False            False
# 42140         False    False           False           False            False
# 42141         False     True            True            True             True
#
# ...

# %%
#sum of null values in each column
data.isnull().sum()
# Out:
# COUNTRY_CODE       0
# COUNTRY            1
# GHE_CAUSE_CODE     1
# GHE_CAUSE_TYPE     1
# GHE_CAUSE_TITLE    1
# YEAR               1
# SEX_CODE           1
# AGEGROUP_CODE      1
# POPULATION         1
# DEATHS             1
# DEATHS_RATE        1
# DEATHS_100K        1
# DALY               1
# DALY_RATE          1
# DALY_100K          1
# dtype: int64

# %%
import pandas as pd

# %%
#now show the heatmap of null values
sb.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
#now gonna find particular data and its information with the help of isin()
data.head()
# Out:
#   COUNTRY_CODE                   COUNTRY  GHE_CAUSE_CODE  \
# 0          USA  United States of America           490.0
# 1          USA  United States of America          1400.0
# 2          USA  United States of America          1505.0
# 3          USA  United States of America           390.0
# 4          USA  United States of America           110.0
#
#                                       GHE_CAUSE_TYPE  \
# 0  Communicable, maternal, perinatal and nutritio...
# 1                           Noncommunicable diseases
# 2                           Noncommunicable diseases
# 3  Communicable, maternal, perinatal and nutritio...
# 4  Communicable, maternal, perinatal and nutritio...
#
#                 GHE_CAUSE_TITLE    YEAR SEX_CODE AGEGROUP_CODE  POPULATION  \
# 0           Neonatal conditions  2000.0     FMLE      YEARS0-1   1820819.0
# 1          Congenital anomalies  2000.0     FMLE      YEARS0-1   1820819.0
# ...

# %%
data.columns
# Out:
# Index(['COUNTRY_CODE', 'COUNTRY', 'GHE_CAUSE_CODE', 'GHE_CAUSE_TYPE',
#        'GHE_CAUSE_TITLE', 'YEAR', 'SEX_CODE', 'AGEGROUP_CODE', 'POPULATION',
#        'DEATHS', 'DEATHS_RATE', 'DEATHS_100K', 'DALY', 'DALY_RATE',
#        'DALY_100K'],
#       dtype='object')

# %%
#isin Pandas isin() method is used to filter data frames. isin() method helps in selecting rows with having a particular(or Multiple) values in a data

# %%
data['COUNTRY']
# Out:
# 0        United States of America
# 1        United States of America
# 2        United States of America
# 3        United States of America
# 4        United States of America
#                    ...
# 42137                       China
# 42138                       China
# 42139                       China
# 42140                       China
# 42141                         NaN
# Name: COUNTRY, Length: 42142, dtype: object

# %%
data['GHE_CAUSE_TITLE']
# Out:
# 0                 Neonatal conditions
# 1                Congenital anomalies
# 2        Sudden infant death syndrome
# 3        Lower respiratory infections
# 4                 Diarrhoeal diseases
#                      ...
# 42137                Bipolar disorder
# 42138           Non-migraine headache
# 42139                  Genital herpes
# 42140                       Cataracts
# 42141                             NaN
# Name: GHE_CAUSE_TITLE, Length: 42142, dtype: object

# %%
data[data['GHE_CAUSE_TYPE'].isin(['Noncommunicable diseases'])] #this gonna show a paricular data
# Out:
#       COUNTRY_CODE                   COUNTRY  GHE_CAUSE_CODE  \
# 1              USA  United States of America          1400.0
# 2              USA  United States of America          1505.0
# 6              USA  United States of America          1242.0
# 7              USA  United States of America          1150.0
# 10             USA  United States of America          1140.0
# ...            ...                       ...             ...
# 42135          CHN                     China           890.0
# 42136          CHN                     China          1370.0
# 42137          CHN                     China           840.0
# 42138          CHN                     China          1000.0
# 42140          CHN                     China          1040.0
#
#                  GHE_CAUSE_TYPE                             GHE_CAUSE_TITLE  \
# 1      Noncommunicable diseases                        Congenital anomalies
# 2      Noncommunicable diseases                Sudden infant death syndrome
# ...

# %%
data.columns
# Out:
# Index(['COUNTRY_CODE', 'COUNTRY', 'GHE_CAUSE_CODE', 'GHE_CAUSE_TYPE',
#        'GHE_CAUSE_TITLE', 'YEAR', 'SEX_CODE', 'AGEGROUP_CODE', 'POPULATION',
#        'DEATHS', 'DEATHS_RATE', 'DEATHS_100K', 'DALY', 'DALY_RATE',
#        'DALY_100K'],
#       dtype='object')

# %%
data.head()
# Out:
#   COUNTRY_CODE                   COUNTRY  GHE_CAUSE_CODE  \
# 0          USA  United States of America           490.0
# 1          USA  United States of America          1400.0
# 2          USA  United States of America          1505.0
# 3          USA  United States of America           390.0
# 4          USA  United States of America           110.0
#
#                                       GHE_CAUSE_TYPE  \
# 0  Communicable, maternal, perinatal and nutritio...
# 1                           Noncommunicable diseases
# 2                           Noncommunicable diseases
# 3  Communicable, maternal, perinatal and nutritio...
# 4  Communicable, maternal, perinatal and nutritio...
#
#                 GHE_CAUSE_TITLE    YEAR SEX_CODE AGEGROUP_CODE  POPULATION  \
# 0           Neonatal conditions  2000.0     FMLE      YEARS0-1   1820819.0
# 1          Congenital anomalies  2000.0     FMLE      YEARS0-1   1820819.0
# ...

# %%
#now gonna create a new column where it going to store a date related info
data['data_y']=pd.to_datetime(data['YEAR']) #converting old data to datetimme and creating a new column for storing tha data

# %%
data.head()
# Out:
#   COUNTRY_CODE                   COUNTRY  GHE_CAUSE_CODE  \
# 0          USA  United States of America           490.0
# 1          USA  United States of America          1400.0
# 2          USA  United States of America          1505.0
# 3          USA  United States of America           390.0
# 4          USA  United States of America           110.0
#
#                                       GHE_CAUSE_TYPE  \
# 0  Communicable, maternal, perinatal and nutritio...
# 1                           Noncommunicable diseases
# 2                           Noncommunicable diseases
# 3  Communicable, maternal, perinatal and nutritio...
# 4  Communicable, maternal, perinatal and nutritio...
#
#                 GHE_CAUSE_TITLE    YEAR SEX_CODE AGEGROUP_CODE  POPULATION  \
# 0           Neonatal conditions  2000.0     FMLE      YEARS0-1   1820819.0
# 1          Congenital anomalies  2000.0     FMLE      YEARS0-1   1820819.0
# ...

# %%
data.groupby('POPULATION').POPULATION.count() #grouping category and count total number of data for POPULATION
# Out:
# POPULATION
# 1196768.0     131
# 1431069.0     131
# 1441616.0     131
# 1782135.0     131
# 1820819.0     131
#              ...
# 65224612.0    131
# 65867472.0    131
# 67499615.0    131
# 67937105.0    131
# 68213487.0    131
# Name: POPULATION, Length: 322, dtype: int64

# %%
plt.bar(data.groupby('POPULATION').POPULATION.count(),height=10)
# Out:
# <BarContainer object of 322 artists>

# %%
#plot bar graph use countplot in seaborn
sb.countplot(data['POPULATION'])
# Out:
# <Axes: ylabel='count'>

# %%
data=pd.read_csv('/content/data.csv')
data
# Out:
#        COUNTRY_CODE                   COUNTRY  GHE_CAUSE_CODE  \
# 0               USA  United States of America             490
# 1               USA  United States of America            1400
# 2               USA  United States of America            1505
# 3               USA  United States of America             390
# 4               USA  United States of America             110
# ...             ...                       ...             ...
# 622245          THA                  Thailand            1050
# 622246          THA                  Thailand            1360
# 622247          THA                  Thailand             360
# 622248          THA                  Thailand            1370
# 622249          THA                  Thailand            1320
#
#                                            GHE_CAUSE_TYPE  \
# 0       Communicable, maternal, perinatal and nutritio...
# 1                                Noncommunicable diseases
# ...

# %%
print(data.POPULATION)
# Out:
# 0         1820819.0
# 1         1820819.0
# 2         1820819.0
# 3         1820819.0
# 4         1820819.0
#             ...
# 622245     306585.0
# 622246     306585.0
# 622247     306585.0
# 622248     306585.0
# 622249     306585.0
# Name: POPULATION, Length: 622250, dtype: float64
