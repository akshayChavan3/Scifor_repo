# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
#load and read data of world population
data=pd.read_csv('/content/data.csv')
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-cbf74aba9a20> in <cell line: 2>()
#       1 #load and read data of world population
# ----> 2 data=pd.read_csv('/content/data.csv')
#       3 data
#
# NameError: name 'pd' is not defined

# %%
#call a head function to print some rows and columns ,by default it can print only 5.
data.head()
# Out:
#   COUNTRY_CODE                   COUNTRY  GHE_CAUSE_CODE  \
# 0          USA  United States of America             490
# 1          USA  United States of America            1400
# 2          USA  United States of America            1505
# 3          USA  United States of America             390
# 4          USA  United States of America             110
#
#                                       GHE_CAUSE_TYPE  \
# 0  Communicable, maternal, perinatal and nutritio...
# 1                           Noncommunicable diseases
# 2                           Noncommunicable diseases
# 3  Communicable, maternal, perinatal and nutritio...
# 4  Communicable, maternal, perinatal and nutritio...
#
#                 GHE_CAUSE_TITLE    YEAR SEX_CODE AGEGROUP_CODE  POPULATION  \
# 0           Neonatal conditions  2000.0     FMLE      YEARS0-1   1820819.0
# 1          Congenital anomalies  2000.0     FMLE      YEARS0-1   1820819.0
# ...

# %%
#call tail function to print from bottom record by default 5
data.tail()
# Out:
#        COUNTRY_CODE                                            COUNTRY  \
# 114054          GBR  United Kingdom of Great Britain and Northern I...
# 114055          GBR  United Kingdom of Great Britain and Northern I...
# 114056          GBR  United Kingdom of Great Britain and Northern I...
# 114057          GBR  United Kingdom of Great Britain and Northern I...
# 114058          GBR  United Kingdom of Great Britain and Northern I...
#
#         GHE_CAUSE_CODE                                     GHE_CAUSE_TYPE  \
# 114054             160  Communicable, maternal, perinatal and nutritio...
# 114055             811                           Noncommunicable diseases
# 114056            1470                           Noncommunicable diseases
# 114057              80  Communicable, maternal, perinatal and nutritio...
# 114058            1505                                       Noncommunica
#
#         GHE_CAUSE_TITLE    YEAR SEX_CODE AGEGROUP_CODE  POPULATION  DEATHS  \
# ...

# %%
#finding a shape means how many rows and columns are there
data.shape
# Out:
# (114059, 15)

# %%
#total number of data values
data.size
# Out:
# 1710885

# %%
data.duplicated() #finding duplicate values or data
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 114054    False
# 114055    False
# 114056    False
# 114057    False
# 114058    False
# Length: 114059, dtype: bool

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [COUNTRY_CODE, COUNTRY, GHE_CAUSE_CODE, GHE_CAUSE_TYPE, GHE_CAUSE_TITLE, YEAR, SEX_CODE, AGEGROUP_CODE, POPULATION, DEATHS, DEATHS_RATE, DEATHS_100K, DALY, DALY_RATE, DALY_100K]
# Index: []

# %%
#finding empty values
data.isnull()
# Out:
#         COUNTRY_CODE  COUNTRY  GHE_CAUSE_CODE  GHE_CAUSE_TYPE  \
# 0              False    False           False           False
# 1              False    False           False           False
# 2              False    False           False           False
# 3              False    False           False           False
# 4              False    False           False           False
# ...              ...      ...             ...             ...
# 114054         False    False           False           False
# 114055         False    False           False           False
# 114056         False    False           False           False
# 114057         False    False           False           False
# 114058         False    False           False           False
#
#         GHE_CAUSE_TITLE   YEAR  SEX_CODE  AGEGROUP_CODE  POPULATION  DEATHS  \
# 0                 False  False     False          False       False   False
# ...

# %%
#sum of null values in each column
data.isnull().sum()
# Out:
# COUNTRY_CODE       0
# COUNTRY            0
# GHE_CAUSE_CODE     0
# GHE_CAUSE_TYPE     0
# GHE_CAUSE_TITLE    1
# YEAR               1
# SEX_CODE           1
# AGEGROUP_CODE      1
# POPULATION         1
# DEATHS             1
# DEATHS_RATE        1
# DEATHS_100K        1
# DALY               1
# DALY_RATE          1
# DALY_100K          1
# dtype: int64

# %%
#now show the heatmap of null values
sb.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
#now gonna find particular data and its information with the help of isin()
data.head()
# Out:
#   COUNTRY_CODE                   COUNTRY  GHE_CAUSE_CODE  \
# 0          USA  United States of America             490
# 1          USA  United States of America            1400
# 2          USA  United States of America            1505
# 3          USA  United States of America             390
# 4          USA  United States of America             110
#
#                                       GHE_CAUSE_TYPE  \
# 0  Communicable, maternal, perinatal and nutritio...
# 1                           Noncommunicable diseases
# 2                           Noncommunicable diseases
# 3  Communicable, maternal, perinatal and nutritio...
# 4  Communicable, maternal, perinatal and nutritio...
#
#                 GHE_CAUSE_TITLE    YEAR SEX_CODE AGEGROUP_CODE  POPULATION  \
# 0           Neonatal conditions  2000.0     FMLE      YEARS0-1   1820819.0
# 1          Congenital anomalies  2000.0     FMLE      YEARS0-1   1820819.0
# ...

# %%
data.columns
# Out:
# Index(['COUNTRY_CODE', 'COUNTRY', 'GHE_CAUSE_CODE', 'GHE_CAUSE_TYPE',
#        'GHE_CAUSE_TITLE', 'YEAR', 'SEX_CODE', 'AGEGROUP_CODE', 'POPULATION',
#        'DEATHS', 'DEATHS_RATE', 'DEATHS_100K', 'DALY', 'DALY_RATE',
#        'DALY_100K'],
#       dtype='object')

# %%
#isin Pandas isin() method is used to filter data frames. isin() method helps in selecting rows with having a particular(or Multiple) values in a data

# %%
data['COUNTRY_CODE']
# Out:
# 0         USA
# 1         USA
# 2         USA
# 3         USA
# 4         USA
#          ...
# 114054    GBR
# 114055    GBR
# 114056    GBR
# 114057    GBR
# 114058    GBR
# Name: COUNTRY_CODE, Length: 114059, dtype: object

# %%
data[data['GHE_CAUSE_CODE'].isin(['490'])] #this gonna show a paricular data
# Out:
# Empty DataFrame
# Columns: [COUNTRY_CODE, COUNTRY, GHE_CAUSE_CODE, GHE_CAUSE_TYPE, GHE_CAUSE_TITLE, YEAR, SEX_CODE, AGEGROUP_CODE, POPULATION, DEATHS, DEATHS_RATE, DEATHS_100K, DALY, DALY_RATE, DALY_100K]
# Index: []

# %%
#now gonna find,in which year most tv shows and movies were released
data.dtypes
# Out:
# COUNTRY_CODE        object
# COUNTRY             object
# GHE_CAUSE_CODE       int64
# GHE_CAUSE_TYPE      object
# GHE_CAUSE_TITLE     object
# YEAR               float64
# SEX_CODE            object
# AGEGROUP_CODE       object
# POPULATION         float64
# DEATHS             float64
# DEATHS_RATE        float64
# DEATHS_100K        float64
# DALY               float64
# DALY_RATE          float64
# DALY_100K          float64
# dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/data.csv")

# %%
#load and read data of world population
data=pd.read_csv('/content/data.csv')
data
# Out:
#        COUNTRY_CODE                   COUNTRY  GHE_CAUSE_CODE  \
# 0               USA  United States of America             490
# 1               USA  United States of America            1400
# 2               USA  United States of America            1505
# 3               USA  United States of America             390
# 4               USA  United States of America             110
# ...             ...                       ...             ...
# 622245          THA                  Thailand            1050
# 622246          THA                  Thailand            1360
# 622247          THA                  Thailand             360
# 622248          THA                  Thailand            1370
# 622249          THA                  Thailand            1320
#
#                                            GHE_CAUSE_TYPE  \
# 0       Communicable, maternal, perinatal and nutritio...
# 1                                Noncommunicable diseases
# ...

# %%
print(df.columns)
# Out:
# Index(['COUNTRY_CODE', 'COUNTRY', 'GHE_CAUSE_CODE', 'GHE_CAUSE_TYPE',
#        'GHE_CAUSE_TITLE', 'YEAR', 'SEX_CODE', 'AGEGROUP_CODE', 'POPULATION',
#        'DEATHS', 'DEATHS_RATE', 'DEATHS_100K', 'DALY', 'DALY_RATE',
#        'DALY_100K'],
#       dtype='object')
